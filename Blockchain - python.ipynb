# %%
import datetime
import hashlib

# %%
class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) + "\n--------------"

# %%
class Blockchain:
    diff=20
    maxNonce = 2**32
    target = 2**(256-diff)
    
    block = Block ("Genesis")
    dummy=head=block
    
    def add(self,block):
        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

blockchain = Blockchain()

for n in range(10):
    blockchain.mine(Block("Block " + str(n+1)))

while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: fa1c2020a008886a3d4cedd8174cf42c7e82b50f5a03209a793f5ff198277d3c
# BlockNo: 1
# Block Data: Block 1
# Hashes: 699073
# --------------
# Block Hash: 52bcb0fd081732b33d6fdb273e5c635e4c1b7ab32625b8b87f1998d49c74c081
# BlockNo: 2
# Block Data: Block 2
# Hashes: 1817731
# --------------
# Block Hash: 9306025ed921f484daf5a0d7dbb58133915c9218a04c2071750308a0e17c26ba
# BlockNo: 3
# Block Data: Block 3
# Hashes: 413688
# --------------
# Block Hash: a54208a186f895fad1a2864837d9a96b76a99aca43a565141c20b4bad71170fa
# BlockNo: 4
# Block Data: Block 4
# Hashes: 1212880
# --------------
# Block Hash: da0ef3b16e74a0341cb70403d52f59147ae938d43226deae14f14d1236f96da7
# BlockNo: 5
# Block Data: Block 5
# Hashes: 325304
# --------------
# Block Hash: ba9d6aa8fae8bed76592f705e824d5bc6d2a0a1125475e3aeeb96b9705774b9e
# BlockNo: 6
# Block Data: Block 6
# Hashes: 5136993
# --------------
# Block Hash: 6ce4d2d522ff995188b445f564503aefcf53ae08b2b0268e39d92ecd0e8210ce
# BlockNo: 7
# Block Data: Block 7
# Hashes: 309733
# --------------
# Block Hash: 0bb1605f5922811f0d6b1a4d69312e8b093360034f7cc07e6b246dd5540fcd84
# BlockNo: 8
# Block Data: Block 8
# Hashes: 143528
# --------------
# Block Hash: 1cc87f22238013aec5b8694ca4364c37484dbdadef6241db8d3761b2d25f6dc8
# BlockNo: 9
# Block Data: Block 9
# Hashes: 841793
# --------------
# Block Hash: 7821a987d7668d2e03e610bd510edcf8f75748b438f09b46d913c020c51cc6e7
# BlockNo: 10
# Block Data: Block 10
# Hashes: 195416
# --------------
# Block Hash: 8de00b2127b72063971046c0bed8a836cb723e555b7792062f4adb591acac7c0
# BlockNo: 0
# Block Data: Genesis
# Hashes: 0
# --------------
# Block Hash: fa1c2020a008886a3d4cedd8174cf42c7e82b50f5a03209a793f5ff198277d3c
# BlockNo: 1
# Block Data: Block 1
# Hashes: 699073
# --------------
# Block Hash: 52bcb0fd081732b33d6fdb273e5c635e4c1b7ab32625b8b87f1998d49c74c081
# BlockNo: 2
# Block Data: Block 2
# Hashes: 1817731
# --------------
# Block Hash: 9306025ed921f484daf5a0d7dbb58133915c9218a04c2071750308a0e17c26ba
# BlockNo: 3
# Block Data: Block 3
# Hashes: 413688
# --------------
# Block Hash: a54208a186f895fad1a2864837d9a96b76a99aca43a565141c20b4bad71170fa
# BlockNo: 4
# Block Data: Block 4
# Hashes: 1212880
# --------------
# Block Hash: da0ef3b16e74a0341cb70403d52f59147ae938d43226deae14f14d1236f96da7
# BlockNo: 5
# Block Data: Block 5
# Hashes: 325304
# --------------
# Block Hash: ba9d6aa8fae8bed76592f705e824d5bc6d2a0a1125475e3aeeb96b9705774b9e
# BlockNo: 6
# Block Data: Block 6
# Hashes: 5136993
# --------------
# Block Hash: 6ce4d2d522ff995188b445f564503aefcf53ae08b2b0268e39d92ecd0e8210ce
# BlockNo: 7
# Block Data: Block 7
# Hashes: 309733
# --------------
# Block Hash: 0bb1605f5922811f0d6b1a4d69312e8b093360034f7cc07e6b246dd5540fcd84
# BlockNo: 8
# Block Data: Block 8
# Hashes: 143528
# --------------
# Block Hash: 1cc87f22238013aec5b8694ca4364c37484dbdadef6241db8d3761b2d25f6dc8
# BlockNo: 9
# Block Data: Block 9
# Hashes: 841793
# --------------
# Block Hash: 7821a987d7668d2e03e610bd510edcf8f75748b438f09b46d913c020c51cc6e7
# BlockNo: 10
# Block Data: Block 10
# Hashes: 195416
# --------------
